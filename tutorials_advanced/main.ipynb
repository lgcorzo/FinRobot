# %% [markdown]
# # SMA Crossover Strategy Project Guideline
#
# ## Project Overview
# This project implements and backtests a Simple Moving Average (SMA) Crossover trading strategy using Python and the Backtrader library. The strategy is optimized using grid search to find the best parameters.
#
# ## Table of Contents
# 1. [Install the necessary libraries & Ignore warnings](#1-install-the-necessary-libraries--ignore-warnings)
# 2. [SMA crossover strategy class](#2-sma-crossover-strategy-class)
# 3. [Define Backtest Engine class](#3-define-backtest-engine-class)
# 4. [Backtest the strategy (find the best parameters by GridSearch)](#4-backtest-the-strategy-find-the-best-parameters-by-gridsearch)
#
# ## Detailed Sections
#
# ### 1. Install the necessary libraries & Ignore warnings
# - Import required modules (warnings, backtrader, yfinance, pandas, numpy, matplotlib, seaborn, tabulate)
# - Configure warnings to be ignored
# - Install necessary libraries using pip (if needed)
#
# ### 2. SMA crossover strategy class
# - Define the `SMACrossStrategy` class, which inherits from `bt.Strategy`
# - Implement strategy logic:
#   - Set up parameters for short/long windows and trade size
#   - Calculate short and long SMAs
#   - Generate buy/sell signals based on SMA crossovers
#   - Manage position sizing and trade execution
#   - Track trades, equity, and drawdown
# - Implement methods for:
#   - Calculating trade size
#   - Handling trade notifications
#
# ### 3. Define Backtest Engine class
# - Create the `BacktestingEngine` class
# - Implement methods for:
#   - Downloading and processing historical data
#   - Running backtests
#   - Analyzing results (including performance metrics like Sharpe ratio, returns, volatility)
#   - Plotting results
#   - Optimizing strategy parameters
#   - Displaying optimization results (including heatmaps and 3D surface plots)
#
# ### 4. Backtest the strategy (find the best parameters by GridSearch)
# - Set up the main execution block
# - Create an instance of the BacktestingEngine
# - Define parameter ranges for optimization:
#   - Short MA range
#   - Long MA range
#   - Trade size range
# - Run the optimization process using grid search
# - Display the best parameters and corresponding performance metrics
# - Plot the results using the optimal parameters
# - Visualize the optimization results using heatmaps and 3D surface plots
#
# ## Next Steps
# - Test the strategy on different assets and timeframes
# - Implement additional technical indicators or entry/exit conditions
# - Explore more sophisticated optimization techniques (e.g., genetic algorithms)
# - Incorporate advanced risk management features
# - Consider real-world factors like slippage and more realistic commission structures
# - Implement walk-forward optimization or out-of-sample testing
#
# By following this guideline, you'll create a comprehensive SMA Crossover Strategy project that covers strategy development, backtesting, optimization, and analysis, aligned with the structure of your existing code.

# %% [markdown]
# # 1. Install the neccecary libraries & Ignore warnings

# %%
# ignore warnings
import warnings

warnings.filterwarnings("ignore")

# Install necessary libraries directly within a Jupyter Notebook
# !pip install backtrader yfinance pandas matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/lgcorzo/miniconda3/envs/finrobot/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %% [markdown]
# # 2. SMA crossover strategy class

# %%
import backtrader as bt
import yfinance as yf
import pandas as pd
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
from itertools import product
from tabulate import tabulate
import seaborn as sns


class SMACrossStrategy(bt.Strategy):
    """
    A Simple Moving Average (SMA) Crossover Strategy.
    This strategy generates buy signals when the short-term SMA crosses above the long-term SMA,
    and sell signals when the short-term SMA crosses below the long-term SMA.
    """

    # Default parameters for the strategy
    params = (
        ("short_window", 5),  # Period for the short-term SMA
        ("long_window", 20),  # Period for the long-term SMA
        (
            "trade_size",
            0.01,
        ),  # Size of each trade as a fraction of the total portfolio value
    )

    def __init__(self):
        """
        Initialize the strategy, setting up indicators and data structures for tracking performance.
        """
        # Calculate and store the short-term and long-term Simple Moving Averages
        self.short_ma = bt.indicators.SimpleMovingAverage(
            self.data.close, period=self.params.short_window
        )
        self.long_ma = bt.indicators.SimpleMovingAverage(
            self.data.close, period=self.params.long_window
        )

        # Create a CrossOver indicator to generate trading signals
        self.crossover = bt.indicators.CrossOver(self.short_ma, self.long_ma)

        # Lists to store trade information and performance metrics
        self.trades = []  # List of all completed trades
        self.trade_returns = []  # Returns of each trade
        self.buys = []  # Dates of buy signals
        self.sells = []  # Dates of sell signals

        # Tracking equity and drawdown
        self.equity = []  # Daily equity values
        self.max_drawdown = 0  # Maximum drawdown experienced
        self.peak_equity = 0  # Highest equity value reached

    def next(self):
        """
        Core strategy logic, called for each bar in the data feed.
        Generates and executes trading signals based on SMA crossovers.
        """
        # Buy signal: short-term SMA crosses above long-term SMA
        if self.crossover > 0:
            if self.position.size < 0:  # If we're currently short, close the position
                self.close()
            self.buy(size=self.calculate_trade_size())  # Open a long position
            self.buys.append(self.data.datetime.date(0))  # Record the buy date

        # Sell signal: short-term SMA crosses below long-term SMA
        elif self.crossover < 0:
            if self.position.size > 0:  # If we're currently long, close the position
                self.close()
            self.sell(size=self.calculate_trade_size())  # Open a short position
            self.sells.append(self.data.datetime.date(0))  # Record the sell date

        # Update equity and drawdown calculations
        current_equity = self.broker.getvalue()
        self.equity.append(current_equity)
        self.peak_equity = max(self.peak_equity, current_equity)
        drawdown = (self.peak_equity - current_equity) / self.peak_equity
        self.max_drawdown = max(self.max_drawdown, drawdown)

    def calculate_trade_size(self):
        """
        Calculate the size of the trade based on the specified trade_size parameter.

        :return: Number of units to trade
        """
        trade_cash = self.broker.getvalue() * self.params.trade_size
        return self.broker.getposition(self.data).size or int(
            trade_cash / self.data.close[0]
        )

    def notify_trade(self, trade):
        """
        Called when a trade is completed. Used to log trade information and calculate returns.

        :param trade: The completed trade object
        """
        if trade.isclosed:
            self.trades.append(trade)
            returns = trade.pnlcomm / trade.price  # Calculate the return of this trade
            self.trade_returns.append(returns)

# %% [markdown]
# # 3. Define Backtest Engine class

# %%
class BacktestingEngine:
    def __init__(self, ticker, start_date, end_date, initial_cash=100000.0, commission=0.001):
        """
        Initialize the BacktestingEngine with given parameters.
        
        :param ticker: Stock symbol to backtest
        :param start_date: Start date for historical data
        :param end_date: End date for historical data
        :param initial_cash: Initial capital for backtesting
        :param commission: Commission rate for trades
        """
        self.ticker = ticker
        self.start_date = start_date
        self.end_date = end_date
        self.initial_cash = initial_cash
        self.commission = commission
        self.data = self.download_data()
        self.results = None

    def download_data(self):
        """
        Download historical price data for the specified ticker and date range.
        
        :return: DataFrame containing historical price data, or None if download fails
        """
        try:
            data = yf.download(self.ticker, start=self.start_date, end=self.end_date)
            if data.empty:
                raise ValueError("No data available for the specified date range")
            data.columns = [col[0] if isinstance(col, tuple) else col for col in data.columns.values]
            return data
        except Exception as e:
            print(f"Error downloading data: {e}")
            return None

    def run_backtest(self, short_window, long_window, trade_size):
        """
        Run a backtest with the specified parameters.
        
        :param short_window: Short-term SMA window
        :param long_window: Long-term SMA window
        :param trade_size: Size of each trade as a fraction of portfolio value
        :return: Results of the backtest, or None if backtest fails
        """
        if self.data is None:
            print("No data available for backtesting")
            return None

        cerebro = bt.Cerebro()
        cerebro.broker.setcash(self.initial_cash)
        cerebro.broker.setcommission(commission=self.commission)
        cerebro.addstrategy(SMACrossStrategy, short_window=int(short_window), long_window=int(long_window), trade_size=trade_size)
        cerebro.adddata(bt.feeds.PandasData(dataname=self.data))
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name="drawdown")
        cerebro.addanalyzer(bt.analyzers.Returns, _name="returns")

        self.results = cerebro.run()
        return self.results[0]

    def analyze_results(self, strategy, print_details=True, print_annual_metrics=True, print_trades_table=False):
        """
        Analyze the results of a backtest.
        
        :param strategy: The strategy object containing backtest results
        :param print_details: Whether to print detailed analysis
        :param print_annual_metrics: Whether to print annualized metrics
        :param print_trades_table: Whether to print a table of all trades
        :return: Dictionary containing key performance metrics
        """
        if strategy is None:
            print("No strategy results to analyze")
            return None

        # Calculate performance metrics
        max_drawdown = strategy.max_drawdown
        total_return = strategy.broker.getvalue() / self.initial_cash - 1
        total_return_cash = strategy.broker.getvalue() - self.initial_cash
        trade_returns = np.array(strategy.trade_returns)
        annual_metrics = self.calculate_annualized_metrics(strategy)
        
        # Print detailed analysis if requested
        if print_details:
            print("\n" + "="*50)
            print(f"Backtest Results for {self.ticker}:")
            print(f"\nDetailed Analysis:")
            print(f"Initial cash: {self.initial_cash}")
            print(f"Final cash: {strategy.broker.getvalue()}")
            print(f"Total return (cash): {total_return_cash:.2f}")
            print(f"Total return (%): {total_return:.2%}")
            print(f"Max drawdown: {max_drawdown:.2%}")
            print(f"Number of trades: {len(strategy.trades)}")

        # Print annualized metrics if requested
        if print_annual_metrics:
            print("\n" + "="*50)
            print("\nAnnualized Metrics:")
            print(f"Annual return: {annual_metrics['Annual Return']:.2%}")
            print(f"Annual volatility: {annual_metrics['Annual Volatility']:.2%}")
            print(f"Sharpe ratio: {annual_metrics['Sharpe Ratio']:.4f}")

        # Print trades table if requested
        if print_trades_table:
            trades = []
            for trade in strategy.trades:
                trades.append([trade.ref, trade.dtopen, trade.dtclose, trade.pnl, trade.pnlcomm])
            trades_df = pd.DataFrame(trades, columns=['Trade ID', 'Open Date', 'Close Date', 'Profit/Loss', 'PnL (incl. commission)'])
            print("\n" + "="*50)
            print("\nTrades:")
            print(tabulate(trades_df, headers='keys', tablefmt='psql'))
        
        # Return key performance metrics
        return {
            'sharpe_ratio': annual_metrics['Sharpe Ratio'],
            'annual_return': annual_metrics['Annual Return'],
            'annual_volatility': annual_metrics['Annual Volatility'],          
            'max_drawdown': max_drawdown,
            'total_return': total_return
        }

    def plot_results(self, short_window, long_window, trade_size):
        """
        Plot the results of a backtest.
        
        :param short_window: Short-term SMA window
        :param long_window: Long-term SMA window
        :param trade_size: Size of each trade as a fraction of portfolio value
        """
        if self.data is None:
            print("No data available for plotting")
            return

        strategy = self.run_backtest(short_window, long_window, trade_size)
        if strategy is None:
            return

        # Create the plot
        fig, ax = plt.subplots(figsize=(15, 8))
        
        # Plot price and SMA lines
        ax.plot(self.data.index, self.data['Close'], label='Close Price', alpha=0.7)
        ax.plot(self.data.index, self.data['Close'].rolling(window=short_window).mean(), label=f'{short_window}-day SMA', alpha=0.7)
        ax.plot(self.data.index, self.data['Close'].rolling(window=long_window).mean(), label=f'{long_window}-day SMA', alpha=0.7)
        
        # Plot buy and sell signals
        ax.scatter(strategy.buys, self.data.loc[strategy.buys]['Close'], marker='^', color='g', label='Buy Signal', alpha=1, s=200)
        ax.scatter(strategy.sells, self.data.loc[strategy.sells]['Close'], marker='v', color='r', label='Sell Signal', alpha=1, s=200)

        # Add vertical lines for buy and sell signals
        for buy_date in strategy.buys:
            ax.axvline(x=buy_date, color='g', linestyle='--', alpha=0.5)
        for sell_date in strategy.sells:
            ax.axvline(x=sell_date, color='r', linestyle='--', alpha=0.5)
        
        # Set plot title and labels
        ax.set_title(f'SMA Crossover Strategy: {self.ticker}\n{self.start_date} to {self.end_date}')
        ax.set_xlabel('Date')
        ax.set_ylabel('Price')
        ax.legend()
        ax.grid(True, alpha=0.3)
        
        plt.xticks(rotation=45)
        
        # Add performance metrics to the plot
        analysis = self.analyze_results(strategy)
        performance_text = (
            f"Sharpe Ratio: {analysis['sharpe_ratio']:.4f}\n"
            f"Annual Return: {analysis['annual_return']:.2%}\n"
            f"Annual Volatility: {analysis['annual_volatility']:.2%}\n"
            f"Max Drawdown: {analysis['max_drawdown']:.2%}\n"
            f"Total Return: {analysis['total_return']:.2%}"
        )
        plt.text(0.05, 0.95, performance_text, transform=ax.transAxes, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))
        plt.tight_layout()
        plt.show()col
        Calculate annualized performance metrics.
        
        :param strategy: The strategy object containing backtest results
        :param risk_free_rate: The risk-free rate for Sharpe ratio calculation
        :return: Dictionary containing annualized metrics
        """
        # Calculate the number of years
        first_date = self.data.index[0].to_pydatetime().date()
        last_date = self.data.index[-1].to_pydatetime().date()
        total_days = (last_date - first_date).days
        annual_factor = 252 / total_days

        # Calculate daily returns
        daily_returns = pd.Series(strategy.equity).pct_change().dropna()

        if len(daily_returns) > 0:
            # Calculate total return and annualize it
            total_return = (strategy.broker.getvalue() / self.initial_cash) - 1
            annual_return = (1 + total_return) ** annual_factor - 1

            # Calculate annualized volatility
            annual_volatility = daily_returns.std() * np.sqrt(252)

            # Calculate Sharpe ratio
            if annual_volatility != 0:
                sharpe_ratio = (annual_return - risk_free_rate) / annual_volatility
            else:
                sharpe_ratio = 0
        else:
            annual_return = annual_volatility = sharpe_ratio = 0

        return {
            "Annual Return": annual_return,
            "Annual Volatility": annual_volatility,
            "Sharpe Ratio": sharpe_ratio,
        }

    def optimize_parameters(self, short_window_range, long_window_range, trade_size_range):
        """
        Optimize strategy parameters using grid search.
        
        :param short_window_range: Range of short-term SMA windows to test
        :param long_window_range: Range of long-term SMA windows to test
        :param trade_size_range: Range of trade sizes to test
        :return: DataFrame containing results of all parameter combinations
        """
        results = []
        for short, long, size in product(short_window_range, long_window_range, trade_size_range):
            if short >= long:
                continue
            strategy = self.run_backtest(short, long, size)
            if strategy is None:
                continue
            analysis = self.analyze_results(strategy, print_details=False, print_annual_metrics=False, print_trades_table=False)
            if analysis is None:
                continue
            results.append({
                'short_window': short,
                'long_window': long,
                'trade_size': size,
                'total_trades': (int)(len(strategy.trades)),
                'sharpe_ratio': analysis['sharpe_ratio'],
                'total_return': analysis['total_return'],
                'max_drawdown': analysis['max_drawdown'],
                'annual_return': analysis['annual_return'],
                'annual_volatility': analysis['annual_volatility']
            })
            print(f"Processed: Short={short}, Long={long}, Trade Size={size:.2%}, Sharpe={analysis['sharpe_ratio']:.4f}, Total Return={analysis['total_return']:.2%}")
        
        results_df = pd.DataFrame(results)
        results_df = results_df.sort_values('sharpe_ratio', ascending=False).reset_index(drop=True)
        
        return results_df

    def display_optimization_results(self, results_df, top_n=10):
        """
        Display the results of parameter optimization.
        
        :param results_df: DataFrame containing optimization results
        :param top_n: Number of top results to display
        """
        print(f"\nTop {top_n} Optimization Results:")
        print(tabulate(results_df.head(top_n), headers='keys', tablefmt='psql', floatfmt=".4f"))
        
        # Create heatmap of Sharpe ratios
        pivot_df = results_df.groupby(['short_window', 'long_window'])['sharpe_ratio'].mean().unstack()
        
        plt.figure(figsize=(12, 8))
        sns.heatmap(pivot_df, annot=True, cmap='YlGnBu', fmt='.2f')
        plt.title('Sharpe Ratio Heatmap')
        plt.xlabel('Long Window')
        plt.ylabel('Short Window')
        plt.show()

        # Create 3D surface plot of Sharpe ratios
        fig = plt.figure(figsize=(12, 8))
        ax = fig.add_subplot(111, projection='3d')
        X, Y = np.meshgrid(pivot_df.columns, pivot_df.index)
        surf = ax.plot_surface(X, Y, pivot_df.values, cmap='viridis')
        ax.set_xlabel('Long Window')
        ax.set_ylabel('Short Window')
        ax.set_zlabel('Sharpe Ratio')
        ax.set_title('3D Surface Plot of Sharpe Ratio')
        fig.colorbar(surf, shrink=0.5, aspect=5)
        plt.show()

# %% [markdown]
# # 4. Backtest the strategy ( find the best parameters by GridSearch )

# %%
if __name__ == "__main__":
    engine = BacktestingEngine("AAPL", "2013-01-01", "2023-12-31")

    # Optimize parameters using grid search
    short_ma_range = range(5, 51, 5)
    long_ma_range = range(10, 101, 10)
    trade_size_range = [0.05, 0.1, 0.15]
    optimized_results = engine.optimize_parameters(
        short_ma_range, long_ma_range, trade_size_range
    )

    # Print best parameters and plot results
    if not optimized_results.empty:
        best_params = optimized_results.iloc[0]
        print(f"\nBest parameters:")
        print(f"Short window: {best_params['short_window']}")
        print(f"Long window: {best_params['long_window']}")
        print(f"Trade size: {best_params['trade_size']:.2%}")
        print(f"Sharpe ratio: {best_params['sharpe_ratio']:.4f}")
        print(f"Total trades: {best_params['total_trades']}")
        print(f"Total return: {best_params['total_return']:.2%}")

        # Plot results with best parameters
        engine.plot_results(
            int(best_params["short_window"]),
            int(best_params["long_window"]),
            best_params["trade_size"],
        )

        # Display optimization results
        engine.display_optimization_results(optimized_results)
    else:
        print("Optimization failed to produce valid results.")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Processed: Short=5, Long=10, Trade Size=5.00%, Sharpe=0.2867, Total Return=39.51%
# Processed: Short=5, Long=10, Trade Size=10.00%, Sharpe=0.2990, Total Return=79.14%
# Processed: Short=5, Long=10, Trade Size=15.00%, Sharpe=0.2362, Total Return=49.92%
# Processed: Short=5, Long=20, Trade Size=5.00%, Sharpe=0.3315, Total Return=46.00%
# Processed: Short=5, Long=20, Trade Size=10.00%, Sharpe=0.3394, Total Return=92.14%
# Processed: Short=5, Long=20, Trade Size=15.00%, Sharpe=0.2843, Total Return=83.16%
# Processed: Short=5, Long=30, Trade Size=5.00%, Sharpe=0.3536, Total Return=47.87%
# Processed: Short=5, Long=30, Trade Size=10.00%, Sharpe=0.3728, Total Return=95.88%
# Processed: Short=5, Long=30, Trade Size=15.00%, Sharpe=0.3850, Total Return=143.88%
# Processed: Short=5, Long=40, Trade Size=5.00%, Sharpe=0.2416, Total Return=33.42%
# Processed: Short=5, Long=40, Trade Size=10.00%, Sharpe=0.2543, Total Return=66.84%
# Processed: Short=5, Long=40, Trade Size=15.00%, Sharpe=0.2815, Total Return=80.16%
# Processed: Short=5, Long=50, Trade Size=5.00%, Sharpe=0.1579, Total Return=22.08%
# Processed: Short=5, Long=50, Trade Size=10.00%, Sharpe=0.1288, Total Return=23.30%
# Processed: Short=5, Long=50, Trade Size=15.00%, Sharpe=0.1369, Total Return=31.66%
# Processed: Short=5, Long=60, Trade Size=5.00%, Sharpe=0.1074, Total Return=15.21%
# Processed: Short=5, Long=60, Trade Size=10.00%, Sharpe=0.1250, Total Return=23.90%
# Processed: Short=5, Long=60, Trade Size=15.00%, Sharpe=0.1890, Total Return=49.17%
# Processed: Short=5, Long=70, Trade Size=5.00%, Sharpe=0.0365, Total Return=5.50%
# Processed: Short=5, Long=70, Trade Size=10.00%, Sharpe=0.1246, Total Return=23.49%
# Processed: Short=5, Long=70, Trade Size=15.00%, Sharpe=0.1394, Total Return=32.81%
# Processed: Short=5, Long=80, Trade Size=5.00%, Sharpe=0.1674, Total Return=23.27%
# Processed: Short=5, Long=80, Trade Size=10.00%, Sharpe=0.1174, Total Return=21.21%
# Processed: Short=5, Long=80, Trade Size=15.00%, Sharpe=0.1984, Total Return=44.29%
# Processed: Short=5, Long=90, Trade Size=5.00%, Sharpe=0.1622, Total Return=23.50%
# Processed: Short=5, Long=90, Trade Size=10.00%, Sharpe=0.1707, Total Return=47.07%
# Processed: Short=5, Long=90, Trade Size=15.00%, Sharpe=0.1849, Total Return=46.32%
# Processed: Short=5, Long=100, Trade Size=5.00%, Sharpe=0.1104, Total Return=15.33%
# Processed: Short=5, Long=100, Trade Size=10.00%, Sharpe=0.1012, Total Return=25.97%
# Processed: Short=5, Long=100, Trade Size=15.00%, Sharpe=0.1249, Total Return=30.77%
# Processed: Short=10, Long=20, Trade Size=5.00%, Sharpe=0.1118, Total Return=14.34%
# Processed: Short=10, Long=20, Trade Size=10.00%, Sharpe=0.1013, Total Return=22.78%
# Processed: Short=10, Long=20, Trade Size=15.00%, Sharpe=0.2248, Total Return=57.88%
# Processed: Short=10, Long=30, Trade Size=5.00%, Sharpe=0.1257, Total Return=18.08%
# Processed: Short=10, Long=30, Trade Size=10.00%, Sharpe=0.1108, Total Return=21.01%
# Processed: Short=10, Long=30, Trade Size=15.00%, Sharpe=0.1076, Total Return=21.70%
# Processed: Short=10, Long=40, Trade Size=5.00%, Sharpe=0.0164, Total Return=2.36%
# Processed: Short=10, Long=40, Trade Size=10.00%, Sharpe=-0.0017, Total Return=-0.29%
# Processed: Short=10, Long=40, Trade Size=15.00%, Sharpe=0.0356, Total Return=7.31%
# Processed: Short=10, Long=50, Trade Size=5.00%, Sharpe=0.1384, Total Return=19.42%
# Processed: Short=10, Long=50, Trade Size=10.00%, Sharpe=0.1437, Total Return=26.27%
# Processed: Short=10, Long=50, Trade Size=15.00%, Sharpe=0.1834, Total Return=42.29%
# Processed: Short=10, Long=60, Trade Size=5.00%, Sharpe=0.2031, Total Return=27.51%
# Processed: Short=10, Long=60, Trade Size=10.00%, Sharpe=0.2136, Total Return=55.10%
# Processed: Short=10, Long=60, Trade Size=15.00%, Sharpe=0.2891, Total Return=76.52%
# Processed: Short=10, Long=70, Trade Size=5.00%, Sharpe=0.1474, Total Return=20.82%
# Processed: Short=10, Long=70, Trade Size=10.00%, Sharpe=0.1207, Total Return=22.68%
# Processed: Short=10, Long=70, Trade Size=15.00%, Sharpe=0.1775, Total Return=42.05%
# Processed: Short=10, Long=80, Trade Size=5.00%, Sharpe=0.1645, Total Return=23.66%
# Processed: Short=10, Long=80, Trade Size=10.00%, Sharpe=0.1690, Total Return=47.38%
# Processed: Short=10, Long=80, Trade Size=15.00%, Sharpe=0.1553, Total Return=38.87%
# Processed: Short=10, Long=90, Trade Size=5.00%, Sharpe=-0.0193, Total Return=-2.50%
# Processed: Short=10, Long=90, Trade Size=10.00%, Sharpe=0.0488, Total Return=11.82%
# Processed: Short=10, Long=90, Trade Size=15.00%, Sharpe=0.1192, Total Return=26.81%
# Processed: Short=10, Long=100, Trade Size=5.00%, Sharpe=-0.0463, Total Return=-6.30%
# Processed: Short=10, Long=100, Trade Size=10.00%, Sharpe=0.0710, Total Return=13.76%
# Processed: Short=10, Long=100, Trade Size=15.00%, Sharpe=0.1033, Total Return=25.08%
# Processed: Short=15, Long=20, Trade Size=5.00%, Sharpe=0.1982, Total Return=26.71%
# Processed: Short=15, Long=20, Trade Size=10.00%, Sharpe=0.2110, Total Return=53.42%
# Processed: Short=15, Long=20, Trade Size=15.00%, Sharpe=0.2365, Total Return=54.91%
# Processed: Short=15, Long=30, Trade Size=5.00%, Sharpe=0.1953, Total Return=26.56%
# Processed: Short=15, Long=30, Trade Size=10.00%, Sharpe=0.2091, Total Return=53.19%
# Processed: Short=15, Long=30, Trade Size=15.00%, Sharpe=0.2858, Total Return=81.28%
# Processed: Short=15, Long=40, Trade Size=5.00%, Sharpe=0.1353, Total Return=19.91%
# Processed: Short=15, Long=40, Trade Size=10.00%, Sharpe=0.0383, Total Return=6.84%
# Processed: Short=15, Long=40, Trade Size=15.00%, Sharpe=0.1975, Total Return=47.20%
# Processed: Short=15, Long=50, Trade Size=5.00%, Sharpe=0.1154, Total Return=16.21%
# Processed: Short=15, Long=50, Trade Size=10.00%, Sharpe=0.1120, Total Return=21.32%
# Processed: Short=15, Long=50, Trade Size=15.00%, Sharpe=0.1710, Total Return=39.82%
# Processed: Short=15, Long=60, Trade Size=5.00%, Sharpe=0.0308, Total Return=4.53%
# Processed: Short=15, Long=60, Trade Size=10.00%, Sharpe=0.0374, Total Return=7.13%
# Processed: Short=15, Long=60, Trade Size=15.00%, Sharpe=0.1035, Total Return=24.35%
# Processed: Short=15, Long=70, Trade Size=5.00%, Sharpe=0.0530, Total Return=7.49%
# Processed: Short=15, Long=70, Trade Size=10.00%, Sharpe=0.1286, Total Return=25.58%
# Processed: Short=15, Long=70, Trade Size=15.00%, Sharpe=0.1655, Total Return=41.54%
# Processed: Short=15, Long=80, Trade Size=5.00%, Sharpe=-0.0794, Total Return=-11.52%
# Processed: Short=15, Long=80, Trade Size=10.00%, Sharpe=0.0701, Total Return=13.98%
# Processed: Short=15, Long=80, Trade Size=15.00%, Sharpe=0.1254, Total Return=30.79%
# Processed: Short=15, Long=90, Trade Size=5.00%, Sharpe=-0.0927, Total Return=-13.30%
# Processed: Short=15, Long=90, Trade Size=10.00%, Sharpe=0.0220, Total Return=3.71%
# Processed: Short=15, Long=90, Trade Size=15.00%, Sharpe=0.0760, Total Return=17.87%
# Processed: Short=15, Long=100, Trade Size=5.00%, Sharpe=-0.0827, Total Return=-11.72%
# Processed: Short=15, Long=100, Trade Size=10.00%, Sharpe=0.0329, Total Return=6.76%
# Processed: Short=15, Long=100, Trade Size=15.00%, Sharpe=-0.1431, Total Return=-21.35%
# Processed: Short=20, Long=30, Trade Size=5.00%, Sharpe=0.1402, Total Return=21.03%
# Processed: Short=20, Long=30, Trade Size=10.00%, Sharpe=0.1156, Total Return=23.14%
# Processed: Short=20, Long=30, Trade Size=15.00%, Sharpe=0.1556, Total Return=38.85%
# Processed: Short=20, Long=40, Trade Size=5.00%, Sharpe=0.1650, Total Return=24.85%
# Processed: Short=20, Long=40, Trade Size=10.00%, Sharpe=0.1678, Total Return=33.94%
# Processed: Short=20, Long=40, Trade Size=15.00%, Sharpe=0.1893, Total Return=46.89%
# Processed: Short=20, Long=50, Trade Size=5.00%, Sharpe=-0.0037, Total Return=-0.53%
# Processed: Short=20, Long=50, Trade Size=10.00%, Sharpe=0.0335, Total Return=5.87%
# Processed: Short=20, Long=50, Trade Size=15.00%, Sharpe=0.1190, Total Return=31.18%
# Processed: Short=20, Long=60, Trade Size=5.00%, Sharpe=0.0364, Total Return=5.31%
# Processed: Short=20, Long=60, Trade Size=10.00%, Sharpe=0.0164, Total Return=2.80%
# Processed: Short=20, Long=60, Trade Size=15.00%, Sharpe=0.1233, Total Return=31.46%
# Processed: Short=20, Long=70, Trade Size=5.00%, Sharpe=-0.0543, Total Return=-7.79%
# Processed: Short=20, Long=70, Trade Size=10.00%, Sharpe=-0.0370, Total Return=-5.97%
# Processed: Short=20, Long=70, Trade Size=15.00%, Sharpe=0.0761, Total Return=17.72%
# Processed: Short=20, Long=80, Trade Size=5.00%, Sharpe=-0.0625, Total Return=-8.92%
# Processed: Short=20, Long=80, Trade Size=10.00%, Sharpe=0.0319, Total Return=5.53%
# Processed: Short=20, Long=80, Trade Size=15.00%, Sharpe=0.0619, Total Return=14.65%
# Processed: Short=20, Long=90, Trade Size=5.00%, Sharpe=-0.0413, Total Return=-5.89%
# Processed: Short=20, Long=90, Trade Size=10.00%, Sharpe=0.0502, Total Return=9.92%
# Processed: Short=20, Long=90, Trade Size=15.00%, Sharpe=0.0994, Total Return=23.94%
# Processed: Short=20, Long=100, Trade Size=5.00%, Sharpe=0.0240, Total Return=3.43%
# Processed: Short=20, Long=100, Trade Size=10.00%, Sharpe=0.0808, Total Return=15.12%
# Processed: Short=20, Long=100, Trade Size=15.00%, Sharpe=0.0985, Total Return=22.20%
# Processed: Short=25, Long=30, Trade Size=5.00%, Sharpe=0.1477, Total Return=21.96%
# Processed: Short=25, Long=30, Trade Size=10.00%, Sharpe=0.1648, Total Return=32.99%
# Processed: Short=25, Long=30, Trade Size=15.00%, Sharpe=0.1807, Total Return=44.29%
# Processed: Short=25, Long=40, Trade Size=5.00%, Sharpe=0.0531, Total Return=8.72%
# Processed: Short=25, Long=40, Trade Size=10.00%, Sharpe=0.0431, Total Return=8.36%
# Processed: Short=25, Long=40, Trade Size=15.00%, Sharpe=0.1242, Total Return=37.39%
# Processed: Short=25, Long=50, Trade Size=5.00%, Sharpe=-0.0225, Total Return=-3.20%
# Processed: Short=25, Long=50, Trade Size=10.00%, Sharpe=-0.0117, Total Return=-1.99%
# Processed: Short=25, Long=50, Trade Size=15.00%, Sharpe=0.1018, Total Return=26.22%
# Processed: Short=25, Long=60, Trade Size=5.00%, Sharpe=-0.0613, Total Return=-8.95%
# Processed: Short=25, Long=60, Trade Size=10.00%, Sharpe=-0.0528, Total Return=-8.53%
# Processed: Short=25, Long=60, Trade Size=15.00%, Sharpe=0.0544, Total Return=13.92%
# Processed: Short=25, Long=70, Trade Size=5.00%, Sharpe=-0.1313, Total Return=-19.84%
# Processed: Short=25, Long=70, Trade Size=10.00%, Sharpe=-0.0589, Total Return=-9.45%
# Processed: Short=25, Long=70, Trade Size=15.00%, Sharpe=0.0587, Total Return=13.33%
# Processed: Short=25, Long=80, Trade Size=5.00%, Sharpe=-0.0331, Total Return=-4.92%
# Processed: Short=25, Long=80, Trade Size=10.00%, Sharpe=-0.0186, Total Return=-3.16%
# Processed: Short=25, Long=80, Trade Size=15.00%, Sharpe=0.0601, Total Return=14.45%
# Processed: Short=25, Long=90, Trade Size=5.00%, Sharpe=0.0492, Total Return=7.03%
# Processed: Short=25, Long=90, Trade Size=10.00%, Sharpe=0.0986, Total Return=19.01%
# Processed: Short=25, Long=90, Trade Size=15.00%, Sharpe=0.1265, Total Return=30.27%
# Processed: Short=25, Long=100, Trade Size=5.00%, Sharpe=-0.0821, Total Return=-11.67%
# Processed: Short=25, Long=100, Trade Size=10.00%, Sharpe=0.0360, Total Return=7.15%
# Processed: Short=25, Long=100, Trade Size=15.00%, Sharpe=0.0575, Total Return=13.51%
# Processed: Short=30, Long=40, Trade Size=5.00%, Sharpe=0.1251, Total Return=20.47%
# Processed: Short=30, Long=40, Trade Size=10.00%, Sharpe=0.0685, Total Return=12.64%
# Processed: Short=30, Long=40, Trade Size=15.00%, Sharpe=0.1753, Total Return=49.21%
# Processed: Short=30, Long=50, Trade Size=5.00%, Sharpe=-0.0541, Total Return=-7.49%
# Processed: Short=30, Long=50, Trade Size=10.00%, Sharpe=-0.0001, Total Return=-0.02%
# Processed: Short=30, Long=50, Trade Size=15.00%, Sharpe=0.1084, Total Return=28.72%
# Processed: Short=30, Long=60, Trade Size=5.00%, Sharpe=-0.1469, Total Return=-22.15%
# Processed: Short=30, Long=60, Trade Size=10.00%, Sharpe=-0.1296, Total Return=-20.90%
# Processed: Short=30, Long=60, Trade Size=15.00%, Sharpe=-0.2172, Total Return=-32.88%
# Processed: Short=30, Long=70, Trade Size=5.00%, Sharpe=-0.0328, Total Return=-4.86%
# Processed: Short=30, Long=70, Trade Size=10.00%, Sharpe=0.0086, Total Return=1.50%
# Processed: Short=30, Long=70, Trade Size=15.00%, Sharpe=0.0595, Total Return=15.08%
# Processed: Short=30, Long=80, Trade Size=5.00%, Sharpe=-0.0051, Total Return=-0.71%
# Processed: Short=30, Long=80, Trade Size=10.00%, Sharpe=-0.0307, Total Return=-7.13%
# Processed: Short=30, Long=80, Trade Size=15.00%, Sharpe=0.0795, Total Return=17.52%
# Processed: Short=30, Long=90, Trade Size=5.00%, Sharpe=-0.0428, Total Return=-5.93%
# Processed: Short=30, Long=90, Trade Size=10.00%, Sharpe=0.0362, Total Return=7.64%
# Processed: Short=30, Long=90, Trade Size=15.00%, Sharpe=0.0995, Total Return=23.59%
# Processed: Short=30, Long=100, Trade Size=5.00%, Sharpe=0.0060, Total Return=0.83%
# Processed: Short=30, Long=100, Trade Size=10.00%, Sharpe=-0.0179, Total Return=-4.12%
# Processed: Short=30, Long=100, Trade Size=15.00%, Sharpe=0.1283, Total Return=32.69%
# Processed: Short=35, Long=40, Trade Size=5.00%, Sharpe=0.0878, Total Return=13.22%
# Processed: Short=35, Long=40, Trade Size=10.00%, Sharpe=0.0522, Total Return=12.97%
# Processed: Short=35, Long=40, Trade Size=15.00%, Sharpe=0.1444, Total Return=40.15%
# Processed: Short=35, Long=50, Trade Size=5.00%, Sharpe=-0.1754, Total Return=-24.58%
# Processed: Short=35, Long=50, Trade Size=10.00%, Sharpe=-0.0687, Total Return=-11.17%
# Processed: Short=35, Long=50, Trade Size=15.00%, Sharpe=-0.1727, Total Return=-27.29%
# Processed: Short=35, Long=60, Trade Size=5.00%, Sharpe=-0.1600, Total Return=-23.08%
# Processed: Short=35, Long=60, Trade Size=10.00%, Sharpe=-0.0609, Total Return=-10.06%
# Processed: Short=35, Long=60, Trade Size=15.00%, Sharpe=0.0600, Total Return=14.64%
# Processed: Short=35, Long=70, Trade Size=5.00%, Sharpe=-0.1847, Total Return=-26.79%
# Processed: Short=35, Long=70, Trade Size=10.00%, Sharpe=-0.0675, Total Return=-10.96%
# Processed: Short=35, Long=70, Trade Size=15.00%, Sharpe=0.0293, Total Return=5.96%
# Processed: Short=35, Long=80, Trade Size=5.00%, Sharpe=-0.0320, Total Return=-4.42%
# Processed: Short=35, Long=80, Trade Size=10.00%, Sharpe=0.0400, Total Return=8.14%
# Processed: Short=35, Long=80, Trade Size=15.00%, Sharpe=0.1865, Total Return=48.88%
# Processed: Short=35, Long=90, Trade Size=5.00%, Sharpe=-0.0091, Total Return=-1.29%
# Processed: Short=35, Long=90, Trade Size=10.00%, Sharpe=0.0579, Total Return=12.70%
# Processed: Short=35, Long=90, Trade Size=15.00%, Sharpe=0.1679, Total Return=47.18%
# Processed: Short=35, Long=100, Trade Size=5.00%, Sharpe=0.1043, Total Return=15.29%
# Processed: Short=35, Long=100, Trade Size=10.00%, Sharpe=0.1043, Total Return=29.02%
# Processed: Short=35, Long=100, Trade Size=15.00%, Sharpe=0.1244, Total Return=34.02%
# Processed: Short=40, Long=50, Trade Size=5.00%, Sharpe=-0.2000, Total Return=-26.89%
# Processed: Short=40, Long=50, Trade Size=10.00%, Sharpe=-0.0770, Total Return=-11.43%
# Processed: Short=40, Long=50, Trade Size=15.00%, Sharpe=0.0136, Total Return=2.99%
# Processed: Short=40, Long=60, Trade Size=5.00%, Sharpe=-0.3782, Total Return=-46.38%
# Processed: Short=40, Long=60, Trade Size=10.00%, Sharpe=-0.0163, Total Return=-2.72%
# Processed: Short=40, Long=60, Trade Size=15.00%, Sharpe=0.0688, Total Return=16.45%
# Processed: Short=40, Long=70, Trade Size=5.00%, Sharpe=-0.0400, Total Return=-5.91%
# Processed: Short=40, Long=70, Trade Size=10.00%, Sharpe=0.0014, Total Return=0.24%
# Processed: Short=40, Long=70, Trade Size=15.00%, Sharpe=0.0597, Total Return=12.56%
# Processed: Short=40, Long=80, Trade Size=5.00%, Sharpe=0.0265, Total Return=3.75%
# Processed: Short=40, Long=80, Trade Size=10.00%, Sharpe=0.1160, Total Return=26.11%
# Processed: Short=40, Long=80, Trade Size=15.00%, Sharpe=0.1027, Total Return=24.94%
# Processed: Short=40, Long=90, Trade Size=5.00%, Sharpe=0.0108, Total Return=1.57%
# Processed: Short=40, Long=90, Trade Size=10.00%, Sharpe=0.0647, Total Return=14.17%
# Processed: Short=40, Long=90, Trade Size=15.00%, Sharpe=0.1802, Total Return=49.86%
# Processed: Short=40, Long=100, Trade Size=5.00%, Sharpe=0.0869, Total Return=12.45%
# Processed: Short=40, Long=100, Trade Size=10.00%, Sharpe=0.0988, Total Return=26.49%
# Processed: Short=40, Long=100, Trade Size=15.00%, Sharpe=0.1624, Total Return=42.41%
# Processed: Short=45, Long=50, Trade Size=5.00%, Sharpe=-0.1584, Total Return=-23.10%
# Processed: Short=45, Long=50, Trade Size=10.00%, Sharpe=-0.0594, Total Return=-9.07%
# Processed: Short=45, Long=50, Trade Size=15.00%, Sharpe=0.0947, Total Return=21.11%
# Processed: Short=45, Long=60, Trade Size=5.00%, Sharpe=-0.1224, Total Return=-18.05%
# Processed: Short=45, Long=60, Trade Size=10.00%, Sharpe=-0.0141, Total Return=-2.46%
# Processed: Short=45, Long=60, Trade Size=15.00%, Sharpe=0.0533, Total Return=11.47%
# Processed: Short=45, Long=70, Trade Size=5.00%, Sharpe=-0.0606, Total Return=-9.20%
# Processed: Short=45, Long=70, Trade Size=10.00%, Sharpe=0.0267, Total Return=5.16%
# Processed: Short=45, Long=70, Trade Size=15.00%, Sharpe=-0.1144, Total Return=-18.37%
# Processed: Short=45, Long=80, Trade Size=5.00%, Sharpe=-0.0234, Total Return=-3.43%
# Processed: Short=45, Long=80, Trade Size=10.00%, Sharpe=0.0695, Total Return=15.99%
# Processed: Short=45, Long=80, Trade Size=15.00%, Sharpe=0.1332, Total Return=31.44%
# Processed: Short=45, Long=90, Trade Size=5.00%, Sharpe=0.0170, Total Return=2.60%
# Processed: Short=45, Long=90, Trade Size=10.00%, Sharpe=0.1015, Total Return=24.95%
# Processed: Short=45, Long=90, Trade Size=15.00%, Sharpe=-0.0835, Total Return=-13.21%
# Processed: Short=45, Long=100, Trade Size=5.00%, Sharpe=0.1147, Total Return=17.38%
# Processed: Short=45, Long=100, Trade Size=10.00%, Sharpe=0.1299, Total Return=36.31%
# Processed: Short=45, Long=100, Trade Size=15.00%, Sharpe=0.2388, Total Return=73.92%
# Processed: Short=50, Long=60, Trade Size=5.00%, Sharpe=-0.0183, Total Return=-2.67%
# Processed: Short=50, Long=60, Trade Size=10.00%, Sharpe=0.0193, Total Return=3.72%
# Processed: Short=50, Long=60, Trade Size=15.00%, Sharpe=-0.1414, Total Return=-23.40%
# Processed: Short=50, Long=70, Trade Size=5.00%, Sharpe=-0.0474, Total Return=-7.25%
# Processed: Short=50, Long=70, Trade Size=10.00%, Sharpe=0.1112, Total Return=22.78%
# Processed: Short=50, Long=70, Trade Size=15.00%, Sharpe=0.1075, Total Return=26.68%
# Processed: Short=50, Long=80, Trade Size=5.00%, Sharpe=0.0033, Total Return=0.50%
# Processed: Short=50, Long=80, Trade Size=10.00%, Sharpe=0.1479, Total Return=30.11%
# Processed: Short=50, Long=80, Trade Size=15.00%, Sharpe=0.1313, Total Return=32.09%
# Processed: Short=50, Long=90, Trade Size=5.00%, Sharpe=0.0892, Total Return=13.20%
# Processed: Short=50, Long=90, Trade Size=10.00%, Sharpe=0.1003, Total Return=27.41%
# Processed: Short=50, Long=90, Trade Size=15.00%, Sharpe=0.2265, Total Return=67.29%
# Processed: Short=50, Long=100, Trade Size=5.00%, Sharpe=0.2465, Total Return=36.75%
# Processed: Short=50, Long=100, Trade Size=10.00%, Sharpe=0.2570, Total Return=73.51%
# Processed: Short=50, Long=100, Trade Size=15.00%, Sharpe=0.2646, Total Return=111.22%
#
# Best parameters:
# Short window: 5.0
# Long window: 30.0
# Trade size: 15.00%
# Sharpe ratio: 0.3850
# Total trades: 112.0
# Total return: 143.88%
#
# ==================================================
# Backtest Results for AAPL:
#
# Detailed Analysis:
# Initial cash: 100000.0
# Final cash: 243879.9169161905
# Total return (cash): 143879.92
# Total return (%): 143.88%
# Max drawdown: 26.74%
# Number of trades: 112
#
# ==================================================
#
# Annualized Metrics:
# Annual return: 5.76%
# Annual volatility: 14.96%
# Sharpe ratio: 0.3850
# Top 10 Optimization Results:
# +----+----------------+---------------+--------------+----------------+----------------+----------------+----------------+-----------------+---------------------+
# |    |   short_window |   long_window |   trade_size |   total_trades |   sharpe_ratio |   total_return |   max_drawdown |   annual_return |   annual_volatility |
# |----+----------------+---------------+--------------+----------------+----------------+----------------+----------------+-----------------+---------------------|
# |  0 |         5.0000 |       30.0000 |       0.1500 |       112.0000 |         0.3850 |         1.4388 |         0.2674 |          0.0576 |              0.1496 |
# |  1 |         5.0000 |       30.0000 |       0.1000 |       112.0000 |         0.3728 |         0.9588 |         0.2160 |          0.0431 |              0.1157 |
# |  2 |         5.0000 |       30.0000 |       0.0500 |       112.0000 |         0.3536 |         0.4787 |         0.1369 |          0.0249 |              0.0703 |
# |  3 |         5.0000 |       20.0000 |       0.1000 |       145.0000 |         0.3394 |         0.9214 |         0.1622 |          0.0419 |              0.1233 |
# |  4 |         5.0000 |       20.0000 |       0.0500 |       145.0000 |         0.3315 |         0.4600 |         0.0979 |          0.0241 |              0.0725 |
# |  5 |         5.0000 |       10.0000 |       0.1000 |       283.0000 |         0.2990 |         0.7914 |         0.2467 |          0.0373 |              0.1247 |
# |  6 |        10.0000 |       60.0000 |       0.1500 |        55.0000 |         0.2891 |         0.7652 |         0.2500 |          0.0363 |              0.1257 |
# |  7 |         5.0000 |       10.0000 |       0.0500 |       283.0000 |         0.2867 |         0.3951 |         0.1513 |          0.0211 |              0.0737 |
# |  8 |        15.0000 |       30.0000 |       0.1500 |        85.0000 |         0.2858 |         0.8128 |         0.2053 |          0.0381 |              0.1332 |
# |  9 |         5.0000 |       20.0000 |       0.1500 |       144.0000 |         0.2843 |         0.8316 |         0.2074 |          0.0387 |              0.1362 |
# +----+----------------+---------------+--------------+----------------+----------------+----------------+----------------+-----------------+---------------------+
